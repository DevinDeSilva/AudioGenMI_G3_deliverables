# %%
import torchaudio
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
metadata = pd.read_csv("../data/darpa_timit_dataset/train_data.csv")

# %%
metadata = metadata[~metadata["filename"].isnull()]
metadata = metadata[metadata["filename"].str.contains("WAV.wav")]

# %%
metadata
# Out:
#          index test_or_train dialect_region speaker_id        filename  \
# 0          1.0         TRAIN            DR4      MMDM0   SI681.WAV.wav
# 6          7.0         TRAIN            DR4      MMDM0  SI1311.WAV.wav
# 10        11.0         TRAIN            DR4      MMDM0   SX141.WAV.wav
# 13        14.0         TRAIN            DR4      MMDM0    SX51.WAV.wav
# 23        24.0         TRAIN            DR4      MMDM0   SX411.WAV.wav
# ...        ...           ...            ...        ...             ...
# 23077  23078.0         TRAIN            DR8      MRDM0   SX155.WAV.wav
# 23080  23081.0         TRAIN            DR8      MRDM0   SI965.WAV.wav
# 23088  23089.0         TRAIN            DR8      MRDM0     SA1.WAV.wav
# 23095  23096.0         TRAIN            DR8      MRDM0  SI1044.WAV.wav
# 23097  23098.0         TRAIN            DR8      MRDM0     SA2.WAV.wav
#
#                    path_from_data_dir         path_from_data_dir_windows  \
# 0       TRAIN/DR4/MMDM0/SI681.WAV.wav   TRAIN\\DR4\\MMDM0\\SI681.WAV.wav
# 6      TRAIN/DR4/MMDM0/SI1311.WAV.wav  TRAIN\\DR4\\MMDM0\\SI1311.WAV.wav
# 10      TRAIN/DR4/MMDM0/SX141.WAV.wav   TRAIN\\DR4\\MMDM0\\SX141.WAV.wav
# 13       TRAIN/DR4/MMDM0/SX51.WAV.wav    TRAIN\\DR4\\MMDM0\\SX51.WAV.wav
# 23      TRAIN/DR4/MMDM0/SX411.WAV.wav   TRAIN\\DR4\\MMDM0\\SX411.WAV.wav
# ...                               ...                                ...
# 23077   TRAIN/DR8/MRDM0/SX155.WAV.wav   TRAIN\\DR8\\MRDM0\\SX155.WAV.wav
# 23080   TRAIN/DR8/MRDM0/SI965.WAV.wav   TRAIN\\DR8\\MRDM0\\SI965.WAV.wav
# 23088     TRAIN/DR8/MRDM0/SA1.WAV.wav     TRAIN\\DR8\\MRDM0\\SA1.WAV.wav
# 23095  TRAIN/DR8/MRDM0/SI1044.WAV.wav  TRAIN\\DR8\\MRDM0\\SI1044.WAV.wav
# 23097     TRAIN/DR8/MRDM0/SA2.WAV.wav     TRAIN\\DR8\\MRDM0\\SA2.WAV.wav
#
#       is_converted_audio is_audio is_word_file is_phonetic_file  \
# 0                   True     True        False            False
# 6                   True     True        False            False
# 10                  True     True        False            False
# 13                  True     True        False            False
# 23                  True     True        False            False
# ...                  ...      ...          ...              ...
# 23077               True     True        False              NaN
# 23080               True     True        False              NaN
# 23088               True     True        False              NaN
# 23095               True     True        False              NaN
# 23097               True     True        False              NaN
#
#       is_sentence_file
# 0                False
# 6                False
# 10               False
# 13               False
# 23               False
# ...                ...
# 23077            False
# 23080            False
# 23088            False
# 23095            False
# 23097            False
#
# [4620 rows x 12 columns]

# %%
def load_text(file_path):
    file_path = os.path.join("../data/darpa_timit_dataset/data", file_path)
    file_path = file_path.replace("WAV.wav", "WRD")
    with open(file_path, 'r') as f:
        text = f.read().strip()
        
    text = text.split('\n')
    text = [x.strip().split(' ', 2) for x in text if len(x.split(' ', 2)) == 3]
    return [int(x[0]) for x in text], [int(x[1]) for x in text], [x[2] for x in text]

# %%
def dur(x):
    start, end, _ = load_text(x)
    return -1 * (start[0] - end[-1])

metadata["durations"] = metadata["path_from_data_dir"].apply(dur)

# %%
metadata["sex"] = metadata.speaker_id.str[0]

# %%
list_obj = metadata.groupby(["sex", "dialect_region", "speaker_id"]).agg({
    "filename": list,
    "path_from_data_dir": list,
    "durations": "sum"
})

# %%
list_obj = list_obj.reset_index()

# %%
list_obj["count"] = list_obj["filename"].apply(len)
list_obj = list_obj.sort_values(by="count", ascending=False)

stats = list_obj[["sex", "dialect_region", "speaker_id", "durations"]]

# %%
stats.to_csv("timit_speaker_stats.csv", index=False)

# %%
speaker_id = set()

for s in ["M", "F"]:
    for dr in range(1, 9):
        dr = f"DR{dr}"
        subset = list_obj[(list_obj["sex"] == s) & (list_obj["dialect_region"] == dr)]
        subset = subset.sort_values(by="durations", ascending=False)
        speaker_id.add(subset.iloc[0, 2])

# %%
speaker_id
# Out:
# {'FAPB0',
#  'FECD0',
#  'FGRW0',
#  'FJEN0',
#  'FKLH0',
#  'FLKM0',
#  'FSCN0',
#  'FSJG0',
#  'MCAE0',
#  'MJDE0',
#  'MPMB0',
#  'MRRE0',
#  'MRSO0',
#  'MRTJ0',
#  'MTAB0',
#  'MTQC0'}

# %%
full_data = metadata[metadata["speaker_id"].isin(speaker_id)].reset_index(drop=True)

# %%
full_data["unq_id"] = full_data["speaker_id"] + "_" + full_data["filename"].str.replace(".WAV.wav", "")

# %%
speaker_file = full_data.groupby("speaker_id")['unq_id'].apply(list).reset_index()

# %%
import random

train_ = []
val_ = []
for speaker in speaker_file.to_dict(orient='records'):
    speaker_id = speaker['speaker_id']
    filenames = speaker['unq_id']
    _t = random.sample(filenames, k=int(len(filenames)*0.8))
    train_.extend(_t)
    val_.extend([f for f in filenames if f not in _t])

# %%
len(train_), len(val_)
# Out:
# (128, 32)

# %%
val_
# Out:
# ['FAPB0_SI1693',
#  'FAPB0_SX343',
#  'FECD0_SX158',
#  'FECD0_SX338',
#  'FGRW0_SI1782',
#  'FGRW0_SX72',
#  'FJEN0_SI1677',
#  'FJEN0_SI2307',
#  'FKLH0_SX87',
#  'FKLH0_SX267',
#  'FLKM0_SI686',
#  'FLKM0_SX440',
#  'FSCN0_SI705',
#  'FSCN0_SA1',
#  'FSJG0_SI2200',
#  'FSJG0_SA1',
#  'MCAE0_SX97',
#  'MCAE0_SI2077',
#  'MJDE0_SX310',
#  'MJDE0_SA1',
#  'MPMB0_SI1501',
#  'MPMB0_SX151',
#  'MRRE0_SA1',
#  'MRRE0_SA2',
#  'MRSO0_SX39',
#  'MRSO0_SI1206',
#  'MRTJ0_SI772',
#  'MRTJ0_SX322',
#  'MTAB0_SX222',
#  'MTAB0_SA2',
#  'MTQC0_SI2071',
#  'MTQC0_SA1']

# %%
import random

val_data = full_data[full_data['unq_id'].isin(val_)].reset_index(drop=True)
train_data = full_data[full_data['unq_id'].isin(train_)].reset_index(drop=True)

# %%
val_data.shape, train_data.shape
# Out:
# ((32, 15), (128, 15))

# %%
train_data.to_csv("../data/darpa_timit_dataset/train_data_top20.csv", index=False)
val_data.to_csv("../data/darpa_timit_dataset/val_data_top20.csv", index=False)

# %%
sinc_net_trained = pd.read_csv(
    "../data/darpa_timit_dataset/train_data_unseen.csv"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sinc_net_trained = pd.read_csv(
#       2     "../data/darpa_timit_dataset/train_data_unseen.csv"
#       3 )
#
# File ~/work/academic/sem3/TrustworthyML-assignment/.conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/work/academic/sem3/TrustworthyML-assignment/.conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/work/academic/sem3/TrustworthyML-assignment/.conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/work/academic/sem3/TrustworthyML-assignment/.conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/work/academic/sem3/TrustworthyML-assignment/.conda/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/darpa_timit_dataset/train_data_unseen.csv'

# %%
set1 = set(sinc_net_trained["speaker_id"])
set2 = set(train_data["speaker_id"])

# %%
set1.intersection(set2)
# Out:
# set()
